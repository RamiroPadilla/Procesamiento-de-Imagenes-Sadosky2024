# %% [markdown]
# # **Práctica 3: Segmentación de Imágenes**

# %% [markdown]
# En esta práctica, implementaremos y entrenaremos un modelo U-Net para la tarea de segmentación de imágenes de radiografías de tórax, enfocándonos en segmentación de las estructuras pulmonares.
#
# El modelo U-Net es ampliamente utilizado en la segmentación de imágenes médicas debido a su capacidad para capturar tanto características de bajo nivel como de alto nivel. Para obtener más información sobre el modelo U-Net, consultar el paper original disponible en: [U-Net: Convolutional Networks for Biomedical Image Segmentation](https://arxiv.org/abs/1505.04597).

# %% [markdown]
# Para comenzar, importamos todas las bibliotecas que necesitaremos:

# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms.functional as TF

from torch.utils.data import Dataset, DataLoader
from PIL import Image

# %% [markdown]
# ## **Dataset JSRT**

# %% [markdown]
# Utilizaremos el dataset [JSRT](http://db.jsrt.or.jp/eng.php), que contiene imágenes de radiografías de tórax y sus correspondientes máscaras de segmentación de los pulmones.

# %% [markdown]
# En primer lugar, **descargá la versión reducida del dataset**, que contiene imágenes en resolución 256x256, desde [este enlace](https://drive.google.com/file/d/1-faPhIl7tWxC0AgWx4zmnm1iP5J2YBwu/view?usp=sharing).
#
# Una vez completada la descarga, **descomprimí el archivo .zip y ubicá la carpeta "Segmentation01" en el directorio principal de tu Google Drive**. Así, la estructura de archivos debería quedar de la siguiente manera:
#
# ```
# Mi Unidad/
#     Segmentation01/
#         train/
#         test/
#         list_train.txt
#         list_test.txt
# ```

# %% [markdown]
# Antes de acceder a los datos, es necesario **montar tu Google Drive en el entorno de Google Colab**.
#
# Para ello, ejecutá la celda de código que sigue y seguí las instrucciones:

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# Una vez montado el Drive, podés acceder a la carpeta "Segmentation01" usando la siguiente ruta:

# %%
root_dir = "/content/drive/My Drive/Segmentation01/"

# %% [markdown]
# ## **Lectura, partición y visualización de datos**

# %% [markdown]
# En esta parte, utilizaremos la función `load_image_mask_paths` para leer y cargar las rutas de las imágenes y máscaras correspondientes desde los archivos `list_train.txt` y `list_test.txt`. Estos archivos contienen la **lista de imágenes y máscaras que se utilizarán para entrenamiento y prueba**, respectivamente:

# %%
def load_image_mask_paths(file_path):
    """
    Lee un archivo y devuelve una lista de tuplas donde cada tupla
    contiene la ruta de una imagen y su correspondiente máscara.

    Args:
        file_path (str): Ruta al archivo que contiene las rutas de las imágenes y máscaras.

    Returns:
        list of tuples: Lista de tuplas (image_path, mask_path).
    """
    image_mask_paths = []
    with open(file_path, "r") as file:
        for line in file:
            # Limpia la línea eliminando espacios y reemplaza las barras invertidas con barras normales
            cleaned_line = line.strip().replace("\\", "/")

            # Elimina el prefijo "./" si está presente al inicio de la línea
            if cleaned_line.startswith("./"):
                cleaned_line = cleaned_line[2:]

            # Divide la línea en ruta de imagen y ruta de máscara, y las agrega a la lista
            image_path, mask_path = cleaned_line.split(",")
            image_mask_paths.append((image_path, mask_path))

    return image_mask_paths


# Rutas de los archivos que contienen las listas de imágenes y máscaras para entrenamiento y prueba
train_files = os.path.join(root_dir, "list_train.txt")
test_files = os.path.join(root_dir, "list_test.txt")

# Leemos las rutas de las imágenes y máscaras para entrenamiento y prueba
train_image_mask_paths = load_image_mask_paths(train_files)
test_image_mask_paths = load_image_mask_paths(test_files)

# %% [markdown]
# A continuación, dividimos el conjunto de entrenamiento en dos subconjuntos, **uno para entrenamiento y otro para validación**:

# %%
# Definimos el tamaño del conjunto de validación
val_samples = len(test_image_mask_paths)

# Tamaño del conjunto de entrenamiento
train_samples = len(train_image_mask_paths)

# Generamos índices aleatorios para el conjunto de validación
val_indices = random.sample(range(train_samples), val_samples)

# Separamos los índices en conjuntos de entrenamiento y validación
val_image_mask_paths = [train_image_mask_paths[i] for i in val_indices]
train_image_mask_paths = [train_image_mask_paths[i] for i in range(train_samples) if i not in val_indices]


# Imprimimos la cantidad de ejemplos de entrenamiento, validación y prueba
print(f"Cantidad de ejemplos de entrenamiento: {len(train_image_mask_paths)}")
print(f"Cantidad de ejemplos de validación: {len(val_image_mask_paths)}")
print(f"Cantidad de ejemplos de prueba: {len(test_image_mask_paths)}")
# Out:
# Cantidad de ejemplos de entrenamiento: 40
# Cantidad de ejemplos de validación: 10
# Cantidad de ejemplos de prueba: 10

# %% [markdown]
# Por último, visualizamos algunos ejemplos del conjunto de entrenamiento:

# %%
# Cantidad de ejemplos a visualizar
num_samples_to_display = 2
num_samples_to_display = min(num_samples_to_display, len(train_image_mask_paths))

plt.figure(figsize=(9, num_samples_to_display * 3))

for i, (image_path, mask_path) in enumerate(train_image_mask_paths[:num_samples_to_display]):
    # Cargamos la imagen y la máscara
    image = Image.open(os.path.join(root_dir, image_path)).convert("RGB")
    mask = Image.open(os.path.join(root_dir, mask_path)).convert("L")

    # Convertimos la máscara a un array de numpy y normalizamos
    mask_array = np.array(mask)
    mask_color = np.zeros((*mask_array.shape, 3), dtype=np.uint8)
    mask_color[mask_array > 0] = [255, 0, 0]  # Color rojo para la máscara

    # Convertimos a imágenes PIL
    mask_color_image = Image.fromarray(mask_color)

    # Superponemos la máscara sobre la imagen
    superimposed_image = Image.blend(image, mask_color_image, alpha=0.3)

    # Muestra la imagen original
    plt.subplot(num_samples_to_display, 3, i * 3 + 1)
    plt.imshow(image)
    plt.title(f"Imagen: {os.path.basename(image_path)}")
    plt.axis('off')

    # Muestra la máscara
    plt.subplot(num_samples_to_display, 3, i * 3 + 2)
    plt.imshow(mask, cmap="gray")
    plt.title(f"Máscara: {os.path.basename(mask_path)}")
    plt.axis('off')

    # Muestra la superposición de la máscara sobre la imagen
    plt.subplot(num_samples_to_display, 3, i * 3 + 3)
    plt.imshow(superimposed_image)
    plt.title(f"Superposición")
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Definición de un dataset personalizado en PyTorch**

# %% [markdown]
# Lo que haremos a continuación, será **crear una clase personalizada en PyTorch para manejar y procesar los datos del conjunto JSRT**. Esta clase nos permitirá cargar las imágenes y máscaras, aplicar transformaciones para aumentación de datos, y preparar los datos para el entrenamiento del modelo.
#
# PyTorch proporciona la clase `torch.utils.data.Dataset`, que nos permite crear datasets a medida. Nuestra clase heredará de esta y nos permitirá controlar cómo se cargan los datos y cómo se aplican las transformaciones.
#
# Para obtener más información sobre cómo crear y utilizar datasets en PyTorch, podés consultar la [documentación oficial](https://pytorch.org/docs/stable/data.html#torch.utils.data.Dataset) y algunos tutoriales útiles como [éste](https://pytorch.org/tutorials/beginner/data_loading_tutorial.html).

# %%
class JSRTDataset(Dataset):
    """
    Dataset personalizado para el conjunto de datos JSRT.

    Args:
        root_dir (str): Directorio raíz donde se encuentran las imágenes y máscaras.
        image_mask_paths (list of tuples): Lista de tuplas (image_path, mask_path) con las rutas a las imágenes y máscaras.
        is_train (bool): Indica si el dataset se utiliza para entrenamiento. Si es True, se aplican aumentaciones. Si es False, no se aplican.
    """
    def __init__(self, root_dir, image_mask_paths, is_train=True):
        self.root_dir = root_dir
        self.image_mask_paths = image_mask_paths
        self.is_train = is_train

    def __len__(self):
        """
        Devuelve el número total de ejemplos en el dataset.

        Returns:
            int: Número de ejemplos en el dataset.
        """
        return len(self.image_mask_paths)

    def transform(self, image, mask):
        """
        Aplica las transformaciones a un ejemplo del dataset.

        Args:
            image (PIL.Image): Imagen a transformar.
            mask (PIL.Image): Máscara a transformar.

        Returns:
            tuple: Imagen y máscara transformadas.
        """
        # Aplicamos reflejo horizontal
        if random.random() > 0.5:
            image = TF.hflip(image)
            mask = TF.hflip(mask)

        # Aplicamos rotación
        if random.random() > 0.5:
            angle = int(random.uniform(-5, 5))  # Ángulo de rotación aleatorio entre -5 y 5 grados
            image = TF.rotate(image, angle)
            mask = TF.rotate(mask, angle)

        # Convertimos a tensor
        image = TF.to_tensor(image)
        mask = TF.to_tensor(mask)

        return image, mask

    def __getitem__(self, idx):
        """
        Obtiene una muestra del dataset.

        Args:
            idx (int): Índice de la muestra a obtener.

        Returns:
            tuple: Imagen y máscara en el índice proporcionado, después de aplicar las transformaciones (si las hay).
        """
        image_path, mask_path = self.image_mask_paths[idx]

        # Cargamos la imagen y la máscara
        image = Image.open(os.path.join(self.root_dir, image_path)).convert("L")
        mask = Image.open(os.path.join(self.root_dir, mask_path)).convert("L")

        # Aplicamos las transformaciones si el dataset está en modo entrenamiento
        if self.is_train:
            image, mask = self.transform(image, mask)

        # Nos aseguramos que la imagen y la máscara sean tensores
        if not isinstance(image, torch.Tensor):
            image = TF.to_tensor(image)
        if not isinstance(mask, torch.Tensor):
            mask = TF.to_tensor(mask)

        return image, mask

# %% [markdown]
# ## **Modelo U-Net para segmentación**

# %% [markdown]
# A continuación, procederemos a definir el modelo U-Net que utilizaremos para segmentar imágenes de radiografías de tórax.
#
# Puntos clave a tener en cuenta:
#
# - **Convoluciones:** para simplificar la implementación, utilizar convoluciones que mantengan el tamaño de la entrada. Esto se puede lograr mediante convoluciones 2D con un kernel de 3x3, padding de 1 y stride de 1.
#
# - **Estructura del Encoder:** el encoder de la U-Net deberá tener 4 bloques, cada uno compuesto por dos capas de convolución (usar la función `double_conv`) seguidas de una operación de max pooling (2x2) para reducir las dimensiones espaciales.
#
# - **Estructura del Bottleneck:** en el cuello de botella (bottleneck), aplicar dos capas de convolución adicionales (usar la función `double_conv`) sin max pooling, para capturar características de mayor profundidad sin reducir más las dimensiones espaciales.
#
# - **Estructura del Decoder:** el decoder deberá contener 4 bloques, cada uno comenzando con una convolución transpuesta para aumentar la dimensión espacial, seguida de dos capas de convolución (usar la función `double_conv`).
#
# - **Skip connections:** para implementar las skip connections, utilizar el método `torch.cat` para concatenar los feature maps correspondientes del encoder y el decoder en cada bloque.
#
# - **Función de activación:** utilizaremos la función de activación ReLU (`torch.nn.ReLU()`) en todas las capas convolucionales.
#
# - **Cantidad de feature maps:**
#   - **Bloque 1:** 32 feature maps
#   - **Bloque 2:** 64 feature maps
#   - **Bloque 3:** 128 feature maps
#   - **Bloque 4:** 256 feature maps
#
# - **Capa de salida:** en la última capa del decoder, aplicar una convolución con un kernel de 1x1 para transformar los últimos 32 feature maps en un solo feature map, correspondiente al mapa de segmentación final.

# %%
def double_conv(in_channels, features):
    """
    Realiza dos capas de convolución seguidas de activaciones ReLU.

    Args:
        in_channels (int): Número de canales de entrada.
        features (int): Número de canales de salida.

    Returns:
        nn.Sequential: Secuencia de dos capas convolucionales y activaciones ReLU.
    """
    return nn.Sequential(
        nn.Conv2d(in_channels, features, kernel_size=3, stride=1, padding=1),
        nn.ReLU(inplace=True),
        nn.Conv2d(features, features, kernel_size=3, stride=1, padding=1),
        nn.ReLU(inplace=True),
    )


class UNet(nn.Module):
    """
    Implementación simplificada de la arquitectura U-Net para segmentación de imágenes.

    Args:
        in_channels (int): Número de canales de entrada. Por defecto es 3.
        out_channels (int): Número de canales de salida. Por defecto es 1.
        init_features (int): Número inicial de características. Por defecto es 32.
    """
    def __init__(self, in_channels=3, out_channels=1):
        super().__init__()

        # Encoder: cuatro bloques con capas convolucionales + pooling
        self.encoder1 = double_conv(in_channels, 32)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.encoder2 = double_conv(32, 64)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.encoder3 = double_conv(64, 128)
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.encoder4 = double_conv(128, 256)
        self.pool4 = nn.MaxPool2d(kernel_size=2, stride=2)

        # Bottleneck: parte central de la U-Net que conecta el encoder con el decoder
        self.bottleneck = double_conv(256, 512)

        # Decoder: cuatro bloques con capas de convolución transpuesta + convolución
        self.upconv4 = nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2)
        self.decoder4 = double_conv(256 * 2, 256)
        self.upconv3 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.decoder3 = double_conv(128 * 2, 128)
        self.upconv2 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.decoder2 = double_conv(64 * 2, 64)
        self.upconv1 = nn.ConvTranspose2d(64, 32, kernel_size=2, stride=2)
        self.decoder1 = double_conv(32 * 2, 32)

        # Capa final de convolución para reducir los canales a la cantidad de salida deseada
        self.conv = nn.Conv2d(32, out_channels, kernel_size=1)

    def forward(self, x):
        """
        Realiza la pasada hacia adelante por la U-Net.

        Args:
            x (torch.Tensor): Tensor de entrada con dimensiones (batch_size, in_channels, H, W).

        Returns:
            torch.Tensor: Tensor de salida con dimensiones (batch_size, out_channels, H, W).
        """
        # Encoder
        enc1 = self.encoder1(x)
        enc2 = self.encoder2(self.pool1(enc1))
        enc3 = self.encoder3(self.pool2(enc2))
        enc4 = self.encoder4(self.pool3(enc3))

        # Bottleneck
        bottleneck = self.bottleneck(self.pool4(enc4))

        # Decoder con concatenación y skip connections
        dec4 = self.upconv4(bottleneck)
        dec4 = torch.cat((dec4, enc4), dim=1)  # Concatenación con la salida del encoder (skip connection)
        dec4 = self.decoder4(dec4)
        dec3 = self.upconv3(dec4)
        dec3 = torch.cat((dec3, dec3), dim=1)  # Concatenación con la salida del encoder (skip connection)
        dec3 = self.decoder3(dec3)
        dec2 = self.upconv2(dec3)
        dec2 = torch.cat((dec2, dec2), dim=1)  # Concatenación con la salida del encoder (skip connection)
        dec2 = self.decoder2(dec2)
        dec1 = self.upconv1(dec2)
        dec1 = torch.cat((dec1, dec1), dim=1)  # Concatenación con la salida del encoder (skip connection)
        dec1 = self.decoder1(dec1)

        # Capa de salida
        y = self.conv(dec1)

        return y

# %% [markdown]
# ## **Implementación del entrenamiento**

# %% [markdown]
# En esta etapa, implementaremos el proceso de entrenamiento para el modelo de segmentación U-Net.
#
# Detalles del entrenamiento:
#
# - **Optimizador:** utilizaremos el optimizador **Adam** (podés consultar el paper [acá](https://arxiv.org/abs/1412.6980)), una variante del algoritmo de descenso de gradiente estocástico (SGD). Adam ajusta dinámicamente la tasa de aprendizaje durante el entrenamiento.
#
# - **Función de pérdida:** la función de pérdida será **entropía cruzada binaria** (`nn.BCEWithLogitsLoss`). Esta función es ideal para tareas de segmentación binaria ya que combina la activación sigmoide y la entropía cruzada en una sola operación, simplificando así el cálculo.
#
# - **Tasa de aprendizaje:** la tasa de aprendizaje inicial será de **0.001** (1e-3). Este valor se puede ajustar durante el entrenamiento si se observa que el modelo converge demasiado rápido o demasiado lento.
#
# - **Regularización:** aplicaremos un **weight decay** de **0.00001** (1e-5). Esta técnica ayuda a prevenir el sobreajuste al añadir una penalización al tamaño de los pesos del modelo, promoviendo la generalización.
#
# - **Tamaño del batch:** utilizaremos un tamaño de batch de **4 ejemplos**. Este tamaño puede ser modificado en función de la capacidad de la GPU y de los recursos computacionales disponibles.
#
# - **Número de épocas:** el modelo se entrenará durante **50 épocas**. Si se dispone de una GPU en el entorno de Colab, este número puede incrementarse a **200 épocas** para mejorar la convergencia y el rendimiento del modelo.
#
# ---

# %% [markdown]
# Primero, definimos el modelo, la función de pérdida y el optimizador:

# %%
# Configuramos del dispositivo (GPU si está disponible, de lo contrario CPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Creamos el modelo y los mandamos al dispositivo
model = UNet(in_channels=1, out_channels=1)
model.to(device)

# Función de pérdida y optimizador
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=0.00001)

# %% [markdown]
# A continuación, configuraremos los datasets para entrenamiento, validación y prueba, así como los dataloaders correspondientes para manejar los batches de datos.
#
# Recordemos que:
# - El conjunto de datos de **entrenamiento** se utiliza para **entrenar el modelo**.
# - El conjunto de datos de **validación** se utiliza para **validar el rendimiento del modelo durante el entrenamiento**.
# - El conjunto de datos de **prueba**  se utiliza para **evaluar el rendimiento final del modelo después del entrenamiento**.
#
#
# Los dataloaders para el conjunto de entrenamiento manejarán los batches de datos con un tamaño especificado (en nuestro caso, 4 ejemplos por batch). **Para los conjuntos validación y prueba, fijaremos el tamaño de los batches a 1**. Esto nos va a permitir evaluar las imágenes individualmente.

# %%
# Creamos las instancias de los datasets para entrenamiento, validación y prueba
train_dataset = JSRTDataset(root_dir, train_image_mask_paths, is_train=True)
val_dataset = JSRTDataset(root_dir, val_image_mask_paths, is_train=False)
test_dataset = JSRTDataset(root_dir, test_image_mask_paths, is_train=False)

# Creamos los dataLoaders para manejar los batches de entrenamiento, validación y prueba
batch_size = 4
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(dataset=val_dataset, batch_size=1, shuffle=False)
test_loader = DataLoader(dataset=test_dataset, batch_size=1, shuffle=False)

# %% [markdown]
# A continuación, **implementamos el proceso de entrenamiento del modelo**:

# %%
# Lista para guardar los valores de pérdida durante el entrenamiento
train_loss = []
val_loss = []

# Épocas de entrenamiento
num_epochs = 200
# Inicializamos la pérdida de validación para monitoreo
best_val_loss = float("inf")

# Bucle de entrenamiento
for epoch in range(num_epochs):

    # Entrenamiento
    model.train()
    running_train_loss = 0.0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        outputs = model(inputs) #forward
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_train_loss += loss.item() * inputs.size(0)

    epoch_train_loss = running_train_loss / len(train_loader.dataset)
    train_loss.append(epoch_train_loss)

    # Validación
    model.eval()
    running_val_loss = 0.0

    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)

            running_val_loss += loss.item() * inputs.size(0)

    epoch_val_loss = running_val_loss / len(val_loader.dataset)
    val_loss.append(epoch_val_loss)

    print(f"Época {epoch + 1}/{num_epochs}, Pérdida de entrenamiento: {epoch_train_loss:.4f}, Pérdida de validación: {epoch_val_loss:.4f}")

    # Guardamos el modelo si la pérdida de validación mejora
    if epoch_val_loss < best_val_loss :
        best_val_loss = epoch_val_loss
        torch.save(model.state_dict(), "model_best.pth")
# Out:
# Época 1/200, Pérdida de entrenamiento: 0.6740, Pérdida de validación: 0.6256
# Época 2/200, Pérdida de entrenamiento: 0.6352, Pérdida de validación: 0.6389
# Época 3/200, Pérdida de entrenamiento: 0.6180, Pérdida de validación: 0.6129
# Época 4/200, Pérdida de entrenamiento: 0.6141, Pérdida de validación: 0.6066
# Época 5/200, Pérdida de entrenamiento: 0.7321, Pérdida de validación: 0.6551
# Época 6/200, Pérdida de entrenamiento: 0.6463, Pérdida de validación: 0.6338
# Época 7/200, Pérdida de entrenamiento: 0.7249, Pérdida de validación: 0.6597
# Época 8/200, Pérdida de entrenamiento: 0.6652, Pérdida de validación: 0.6678
# Época 9/200, Pérdida de entrenamiento: 0.6662, Pérdida de validación: 0.6589
# Época 10/200, Pérdida de entrenamiento: 0.6447, Pérdida de validación: 0.6265
# Época 11/200, Pérdida de entrenamiento: 0.6193, Pérdida de validación: 0.6088
# Época 12/200, Pérdida de entrenamiento: 0.6099, Pérdida de validación: 0.5982
# Época 13/200, Pérdida de entrenamiento: 0.5831, Pérdida de validación: 0.5968
# Época 14/200, Pérdida de entrenamiento: 0.5447, Pérdida de validación: 0.5873
# Época 15/200, Pérdida de entrenamiento: 0.5028, Pérdida de validación: 0.4454
# Época 16/200, Pérdida de entrenamiento: 0.4731, Pérdida de validación: 0.5180
# Época 17/200, Pérdida de entrenamiento: 0.4190, Pérdida de validación: 0.4004
# Época 18/200, Pérdida de entrenamiento: 0.3646, Pérdida de validación: 0.3594
# Época 19/200, Pérdida de entrenamiento: 0.3391, Pérdida de validación: 0.3177
# Época 20/200, Pérdida de entrenamiento: 0.3250, Pérdida de validación: 0.2812
# Época 21/200, Pérdida de entrenamiento: 0.2557, Pérdida de validación: 0.2849
# Época 22/200, Pérdida de entrenamiento: 0.2315, Pérdida de validación: 0.2231
# Época 23/200, Pérdida de entrenamiento: 0.2192, Pérdida de validación: 0.2552
# Época 24/200, Pérdida de entrenamiento: 0.2123, Pérdida de validación: 0.2123
# Época 25/200, Pérdida de entrenamiento: 0.1858, Pérdida de validación: 0.1973
# Época 26/200, Pérdida de entrenamiento: 0.2024, Pérdida de validación: 0.1866
# Época 27/200, Pérdida de entrenamiento: 0.1795, Pérdida de validación: 0.1851
# Época 28/200, Pérdida de entrenamiento: 0.1676, Pérdida de validación: 0.1796
# Época 29/200, Pérdida de entrenamiento: 0.1623, Pérdida de validación: 0.1701
# Época 30/200, Pérdida de entrenamiento: 0.1580, Pérdida de validación: 0.1725
# Época 31/200, Pérdida de entrenamiento: 0.1473, Pérdida de validación: 0.1513
# Época 32/200, Pérdida de entrenamiento: 0.1461, Pérdida de validación: 0.2078
# Época 33/200, Pérdida de entrenamiento: 0.1551, Pérdida de validación: 0.1669
# Época 34/200, Pérdida de entrenamiento: 0.1524, Pérdida de validación: 0.1931
# Época 35/200, Pérdida de entrenamiento: 0.1486, Pérdida de validación: 0.1527
# Época 36/200, Pérdida de entrenamiento: 0.1470, Pérdida de validación: 0.1405
# Época 37/200, Pérdida de entrenamiento: 0.1304, Pérdida de validación: 0.1806
# Época 38/200, Pérdida de entrenamiento: 0.1320, Pérdida de validación: 0.1396
# Época 39/200, Pérdida de entrenamiento: 0.1260, Pérdida de validación: 0.1405
# Época 40/200, Pérdida de entrenamiento: 0.1163, Pérdida de validación: 0.1266
# Época 41/200, Pérdida de entrenamiento: 0.1151, Pérdida de validación: 0.1217
# Época 42/200, Pérdida de entrenamiento: 0.1225, Pérdida de validación: 0.1293
# Época 43/200, Pérdida de entrenamiento: 0.1087, Pérdida de validación: 0.1275
# Época 44/200, Pérdida de entrenamiento: 0.1121, Pérdida de validación: 0.1057
# Época 45/200, Pérdida de entrenamiento: 0.1078, Pérdida de validación: 0.1035
# Época 46/200, Pérdida de entrenamiento: 0.1004, Pérdida de validación: 0.1083
# Época 47/200, Pérdida de entrenamiento: 0.0974, Pérdida de validación: 0.1057
# Época 48/200, Pérdida de entrenamiento: 0.0994, Pérdida de validación: 0.0975
# Época 49/200, Pérdida de entrenamiento: 0.0954, Pérdida de validación: 0.0986
# Época 50/200, Pérdida de entrenamiento: 0.0967, Pérdida de validación: 0.0958
# Época 51/200, Pérdida de entrenamiento: 0.0947, Pérdida de validación: 0.0972
# Época 52/200, Pérdida de entrenamiento: 0.0986, Pérdida de validación: 0.0985
# Época 53/200, Pérdida de entrenamiento: 0.0965, Pérdida de validación: 0.0975
# Época 54/200, Pérdida de entrenamiento: 0.0892, Pérdida de validación: 0.0983
# Época 55/200, Pérdida de entrenamiento: 0.0879, Pérdida de validación: 0.0871
# Época 56/200, Pérdida de entrenamiento: 0.0845, Pérdida de validación: 0.0992
# Época 57/200, Pérdida de entrenamiento: 0.0851, Pérdida de validación: 0.0851
# Época 58/200, Pérdida de entrenamiento: 0.0912, Pérdida de validación: 0.0932
# Época 59/200, Pérdida de entrenamiento: 0.0883, Pérdida de validación: 0.0878
# Época 60/200, Pérdida de entrenamiento: 0.0838, Pérdida de validación: 0.0974
# Época 61/200, Pérdida de entrenamiento: 0.0848, Pérdida de validación: 0.0868
# Época 62/200, Pérdida de entrenamiento: 0.0818, Pérdida de validación: 0.0809
# Época 63/200, Pérdida de entrenamiento: 0.0801, Pérdida de validación: 0.0885
# Época 64/200, Pérdida de entrenamiento: 0.0794, Pérdida de validación: 0.0780
# Época 65/200, Pérdida de entrenamiento: 0.0816, Pérdida de validación: 0.0830
# Época 66/200, Pérdida de entrenamiento: 0.0804, Pérdida de validación: 0.0829
# Época 67/200, Pérdida de entrenamiento: 0.0780, Pérdida de validación: 0.0827
# Época 68/200, Pérdida de entrenamiento: 0.0816, Pérdida de validación: 0.0819
# Época 69/200, Pérdida de entrenamiento: 0.0780, Pérdida de validación: 0.0760
# Época 70/200, Pérdida de entrenamiento: 0.0744, Pérdida de validación: 0.0884
# Época 71/200, Pérdida de entrenamiento: 0.0745, Pérdida de validación: 0.0804
# Época 72/200, Pérdida de entrenamiento: 0.0739, Pérdida de validación: 0.0810
# Época 73/200, Pérdida de entrenamiento: 0.0717, Pérdida de validación: 0.0851
# Época 74/200, Pérdida de entrenamiento: 0.0754, Pérdida de validación: 0.0775
# Época 75/200, Pérdida de entrenamiento: 0.0743, Pérdida de validación: 0.0765
# Época 76/200, Pérdida de entrenamiento: 0.0755, Pérdida de validación: 0.0742
# Época 77/200, Pérdida de entrenamiento: 0.0736, Pérdida de validación: 0.0777
# Época 78/200, Pérdida de entrenamiento: 0.0714, Pérdida de validación: 0.0784
# Época 79/200, Pérdida de entrenamiento: 0.0718, Pérdida de validación: 0.0834
# Época 80/200, Pérdida de entrenamiento: 0.0729, Pérdida de validación: 0.0738
# Época 81/200, Pérdida de entrenamiento: 0.0746, Pérdida de validación: 0.0867
# Época 82/200, Pérdida de entrenamiento: 0.0723, Pérdida de validación: 0.0703
# Época 83/200, Pérdida de entrenamiento: 0.0708, Pérdida de validación: 0.0755
# Época 84/200, Pérdida de entrenamiento: 0.0685, Pérdida de validación: 0.0795
# Época 85/200, Pérdida de entrenamiento: 0.0734, Pérdida de validación: 0.0787
# Época 86/200, Pérdida de entrenamiento: 0.0711, Pérdida de validación: 0.0714
# Época 87/200, Pérdida de entrenamiento: 0.0698, Pérdida de validación: 0.0780
# Época 88/200, Pérdida de entrenamiento: 0.0654, Pérdida de validación: 0.0709
# Época 89/200, Pérdida de entrenamiento: 0.0635, Pérdida de validación: 0.0856
# Época 90/200, Pérdida de entrenamiento: 0.0656, Pérdida de validación: 0.0673
# Época 91/200, Pérdida de entrenamiento: 0.0658, Pérdida de validación: 0.0695
# Época 92/200, Pérdida de entrenamiento: 0.0641, Pérdida de validación: 0.0756
# Época 93/200, Pérdida de entrenamiento: 0.0695, Pérdida de validación: 0.0714
# Época 94/200, Pérdida de entrenamiento: 0.0669, Pérdida de validación: 0.0744
# Época 95/200, Pérdida de entrenamiento: 0.0640, Pérdida de validación: 0.0695
# Época 96/200, Pérdida de entrenamiento: 0.0601, Pérdida de validación: 0.0720
# Época 97/200, Pérdida de entrenamiento: 0.0604, Pérdida de validación: 0.0695
# Época 98/200, Pérdida de entrenamiento: 0.0615, Pérdida de validación: 0.0713
# Época 99/200, Pérdida de entrenamiento: 0.0604, Pérdida de validación: 0.0687
# Época 100/200, Pérdida de entrenamiento: 0.0590, Pérdida de validación: 0.0729
# Época 101/200, Pérdida de entrenamiento: 0.0562, Pérdida de validación: 0.0700
# Época 102/200, Pérdida de entrenamiento: 0.0584, Pérdida de validación: 0.0720
# Época 103/200, Pérdida de entrenamiento: 0.0619, Pérdida de validación: 0.0712
# Época 104/200, Pérdida de entrenamiento: 0.0632, Pérdida de validación: 0.0837
# Época 105/200, Pérdida de entrenamiento: 0.0627, Pérdida de validación: 0.0776
# Época 106/200, Pérdida de entrenamiento: 0.0607, Pérdida de validación: 0.0712
# Época 107/200, Pérdida de entrenamiento: 0.0597, Pérdida de validación: 0.0716
# Época 108/200, Pérdida de entrenamiento: 0.0608, Pérdida de validación: 0.0687
# Época 109/200, Pérdida de entrenamiento: 0.0558, Pérdida de validación: 0.0715
# Época 110/200, Pérdida de entrenamiento: 0.0574, Pérdida de validación: 0.0707
# Época 111/200, Pérdida de entrenamiento: 0.0540, Pérdida de validación: 0.0797
# Época 112/200, Pérdida de entrenamiento: 0.0554, Pérdida de validación: 0.0674
# Época 113/200, Pérdida de entrenamiento: 0.0518, Pérdida de validación: 0.0740
# Época 114/200, Pérdida de entrenamiento: 0.0490, Pérdida de validación: 0.0728
# Época 115/200, Pérdida de entrenamiento: 0.0517, Pérdida de validación: 0.0681
# Época 116/200, Pérdida de entrenamiento: 0.0526, Pérdida de validación: 0.0794
# Época 117/200, Pérdida de entrenamiento: 0.0540, Pérdida de validación: 0.0743
# Época 118/200, Pérdida de entrenamiento: 0.0527, Pérdida de validación: 0.0694
# Época 119/200, Pérdida de entrenamiento: 0.0513, Pérdida de validación: 0.0738
# Época 120/200, Pérdida de entrenamiento: 0.0502, Pérdida de validación: 0.0733
# Época 121/200, Pérdida de entrenamiento: 0.0534, Pérdida de validación: 0.0726
# Época 122/200, Pérdida de entrenamiento: 0.0529, Pérdida de validación: 0.0718
# Época 123/200, Pérdida de entrenamiento: 0.0540, Pérdida de validación: 0.0741
# Época 124/200, Pérdida de entrenamiento: 0.0533, Pérdida de validación: 0.0701
# Época 125/200, Pérdida de entrenamiento: 0.0492, Pérdida de validación: 0.0698
# Época 126/200, Pérdida de entrenamiento: 0.0467, Pérdida de validación: 0.0705
# Época 127/200, Pérdida de entrenamiento: 0.0485, Pérdida de validación: 0.0719
# Época 128/200, Pérdida de entrenamiento: 0.0487, Pérdida de validación: 0.0692
# Época 129/200, Pérdida de entrenamiento: 0.0460, Pérdida de validación: 0.0717
# Época 130/200, Pérdida de entrenamiento: 0.0489, Pérdida de validación: 0.0791
# Época 131/200, Pérdida de entrenamiento: 0.0510, Pérdida de validación: 0.0732
# Época 132/200, Pérdida de entrenamiento: 0.0511, Pérdida de validación: 0.0710
# Época 133/200, Pérdida de entrenamiento: 0.0496, Pérdida de validación: 0.0746
# Época 134/200, Pérdida de entrenamiento: 0.0468, Pérdida de validación: 0.0760
# Época 135/200, Pérdida de entrenamiento: 0.0470, Pérdida de validación: 0.0697
# Época 136/200, Pérdida de entrenamiento: 0.0489, Pérdida de validación: 0.0771
# Época 137/200, Pérdida de entrenamiento: 0.0461, Pérdida de validación: 0.0798
# Época 138/200, Pérdida de entrenamiento: 0.0459, Pérdida de validación: 0.0823
# Época 139/200, Pérdida de entrenamiento: 0.0472, Pérdida de validación: 0.0746
# Época 140/200, Pérdida de entrenamiento: 0.0468, Pérdida de validación: 0.0777
# Época 141/200, Pérdida de entrenamiento: 0.0462, Pérdida de validación: 0.0711
# Época 142/200, Pérdida de entrenamiento: 0.0442, Pérdida de validación: 0.0812
# Época 143/200, Pérdida de entrenamiento: 0.0447, Pérdida de validación: 0.0760
# Época 144/200, Pérdida de entrenamiento: 0.0432, Pérdida de validación: 0.0845
# Época 145/200, Pérdida de entrenamiento: 0.0415, Pérdida de validación: 0.0792
# Época 146/200, Pérdida de entrenamiento: 0.0438, Pérdida de validación: 0.0809
# Época 147/200, Pérdida de entrenamiento: 0.0434, Pérdida de validación: 0.0759
# Época 148/200, Pérdida de entrenamiento: 0.0431, Pérdida de validación: 0.0799
# Época 149/200, Pérdida de entrenamiento: 0.0445, Pérdida de validación: 0.0746
# Época 150/200, Pérdida de entrenamiento: 0.0422, Pérdida de validación: 0.0793
# Época 151/200, Pérdida de entrenamiento: 0.0412, Pérdida de validación: 0.0836
# Época 152/200, Pérdida de entrenamiento: 0.0412, Pérdida de validación: 0.0815
# Época 153/200, Pérdida de entrenamiento: 0.0418, Pérdida de validación: 0.0845
# Época 154/200, Pérdida de entrenamiento: 0.0423, Pérdida de validación: 0.0795
# Época 155/200, Pérdida de entrenamiento: 0.0451, Pérdida de validación: 0.0722
# Época 156/200, Pérdida de entrenamiento: 0.0407, Pérdida de validación: 0.0750
# Época 157/200, Pérdida de entrenamiento: 0.0415, Pérdida de validación: 0.0787
# Época 158/200, Pérdida de entrenamiento: 0.0422, Pérdida de validación: 0.0786
# Época 159/200, Pérdida de entrenamiento: 0.0427, Pérdida de validación: 0.0814
# Época 160/200, Pérdida de entrenamiento: 0.0430, Pérdida de validación: 0.0769
# Época 161/200, Pérdida de entrenamiento: 0.0426, Pérdida de validación: 0.0742
# Época 162/200, Pérdida de entrenamiento: 0.0417, Pérdida de validación: 0.0728
# Época 163/200, Pérdida de entrenamiento: 0.0413, Pérdida de validación: 0.0785
# Época 164/200, Pérdida de entrenamiento: 0.0390, Pérdida de validación: 0.0750
# Época 165/200, Pérdida de entrenamiento: 0.0395, Pérdida de validación: 0.0789
# Época 166/200, Pérdida de entrenamiento: 0.0397, Pérdida de validación: 0.0786
# Época 167/200, Pérdida de entrenamiento: 0.0384, Pérdida de validación: 0.0801
# Época 168/200, Pérdida de entrenamiento: 0.0377, Pérdida de validación: 0.0816
# Época 169/200, Pérdida de entrenamiento: 0.0387, Pérdida de validación: 0.0828
# Época 170/200, Pérdida de entrenamiento: 0.0375, Pérdida de validación: 0.0788
# Época 171/200, Pérdida de entrenamiento: 0.0372, Pérdida de validación: 0.0854
# Época 172/200, Pérdida de entrenamiento: 0.0407, Pérdida de validación: 0.0746
# Época 173/200, Pérdida de entrenamiento: 0.0376, Pérdida de validación: 0.0788
# Época 174/200, Pérdida de entrenamiento: 0.0371, Pérdida de validación: 0.0835
# Época 175/200, Pérdida de entrenamiento: 0.0366, Pérdida de validación: 0.0867
# Época 176/200, Pérdida de entrenamiento: 0.0391, Pérdida de validación: 0.0758
# Época 177/200, Pérdida de entrenamiento: 0.0394, Pérdida de validación: 0.0738
# Época 178/200, Pérdida de entrenamiento: 0.0365, Pérdida de validación: 0.0874
# Época 179/200, Pérdida de entrenamiento: 0.0383, Pérdida de validación: 0.0767
# Época 180/200, Pérdida de entrenamiento: 0.0385, Pérdida de validación: 0.0782
# Época 181/200, Pérdida de entrenamiento: 0.0382, Pérdida de validación: 0.0810
# Época 182/200, Pérdida de entrenamiento: 0.0404, Pérdida de validación: 0.0702
# Época 183/200, Pérdida de entrenamiento: 0.0378, Pérdida de validación: 0.0782
# Época 184/200, Pérdida de entrenamiento: 0.0345, Pérdida de validación: 0.0892
# Época 185/200, Pérdida de entrenamiento: 0.0353, Pérdida de validación: 0.0764
# Época 186/200, Pérdida de entrenamiento: 0.0350, Pérdida de validación: 0.0812
# Época 187/200, Pérdida de entrenamiento: 0.0347, Pérdida de validación: 0.0825
# Época 188/200, Pérdida de entrenamiento: 0.0375, Pérdida de validación: 0.0761
# Época 189/200, Pérdida de entrenamiento: 0.0366, Pérdida de validación: 0.0742
# Época 190/200, Pérdida de entrenamiento: 0.0349, Pérdida de validación: 0.0763
# Época 191/200, Pérdida de entrenamiento: 0.0340, Pérdida de validación: 0.0765
# Época 192/200, Pérdida de entrenamiento: 0.0333, Pérdida de validación: 0.0742
# Época 193/200, Pérdida de entrenamiento: 0.0345, Pérdida de validación: 0.0756
# Época 194/200, Pérdida de entrenamiento: 0.0332, Pérdida de validación: 0.0793
# Época 195/200, Pérdida de entrenamiento: 0.0346, Pérdida de validación: 0.0781
# Época 196/200, Pérdida de entrenamiento: 0.0328, Pérdida de validación: 0.0823
# Época 197/200, Pérdida de entrenamiento: 0.0343, Pérdida de validación: 0.0801
# Época 198/200, Pérdida de entrenamiento: 0.0314, Pérdida de validación: 0.0874
# Época 199/200, Pérdida de entrenamiento: 0.0316, Pérdida de validación: 0.0767
# Época 200/200, Pérdida de entrenamiento: 0.0316, Pérdida de validación: 0.0817

# %% [markdown]
# Visualizamos las curvas de entrenamiento y validación:

# %%
plt.figure(figsize=(7, 5))
plt.plot(train_loss, label="Entrenamiento", color="blue")
plt.plot(val_loss, label="Validación", color="red")
plt.xlabel("Época")
plt.ylabel("Pérdida")
plt.title("Curvas de entrenamiento y validación")
plt.legend()
plt.grid(False)
plt.show()

# %% [markdown]
# ## **Evaluación del modelo en el conjunto de prueba**

# %% [markdown]
# Habiendo entrenado el modelo, **vamos a evaluar su desempeño utilizando el conjunto de prueba**.
#
# Para evaluar la calidad de las segmentaciones que el modelo predice, utilizaremos dos métricas:
#
# - **Accuracy (Exactitud):** medimos la exactitud del modelo en la clasificación de cada píxel, calculando la proporción de píxeles correctamente clasificados en relación con el total de píxeles.
#
# - **Dice Coefficient (Coeficiente de Dice):** calculamos el coeficiente de Dice, midiendo la superposición entre la máscara predicha y la máscara verdadera, proporcionando una medida de similitud entre ambas.

# %%
def calculate_accuracy(preds, labels):
    """
    Calcula la exactitud (accuracy) para un batch de predicciones y etiquetas.

    Args:
        preds (torch.Tensor): Predicciones del modelo (tensor de tamaño [1, 1, H, W]).
        labels (torch.Tensor): Etiquetas verdaderas (tensor de tamaño [1, 1, H, W]).

    Returns:
        float: Exactitud del batch.
    """
    # Calculamos la accuracy (total de píxeles correctos dividido por el total de píxeles)
    correct = (preds == labels).float()
    accuracy = correct.sum() / correct.numel()

    return accuracy.item()

def calculate_dice(preds, labels):
    """
    Calcula el coeficiente Dice para un batch de predicciones y etiquetas.

    Args:
        preds (torch.Tensor): Predicciones del modelo (tensor de tamaño [1, 1, H, W]).
        labels (torch.Tensor): Etiquetas verdaderas (tensor de tamaño [1, 1, H, W]).

    Returns:
        float: Coeficiente Dice del batch.
    """
    # Calculamos el Dice
    intersection = (preds * labels).sum()
    union = preds.sum() + labels.sum()
    dice = 2. * intersection / union

    return dice.item()

# %% [markdown]
# Cargamos el modelo entrenado y lo evaluamos el modelo en el conjunto de prueba y calculamos las métricas:

# %%
# Cargamos el modelo entrenado
model.load_state_dict(torch.load("model_best.pth"))
model.to(device)

# Evaluación
model.eval()
total_accuracy = 0.0
total_dice = 0.0

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        outputs = model(inputs)
        preds = (outputs > 0.5).float()

        accuracy = calculate_accuracy(preds, labels)
        total_accuracy += accuracy

        dice = calculate_dice(preds, labels)
        total_dice += dice

average_accuracy = total_accuracy / len(test_loader)
average_dice = total_dice / len(test_loader)

print("Resultados U-Net:\n")
print(f"Accuracy: {average_accuracy:.4f}")
print(f"Dice: {average_dice:.4f}")
# Out:
# <ipython-input-14-e320ed838aab>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("model_best.pth"))
# Resultados U-Net:
#
# Accuracy: 0.9524
# Dice: 0.9206

# %% [markdown]
# Para finalizar, visualicemos algunas predicciones del modelo y comparemos con las máscaras verdaderas:

# %%
# Cantidad de ejemplo a visualizar
num_samples_to_display = 3
num_samples_to_display = min(num_samples_to_display, len(test_loader.dataset))

model.eval()
with torch.no_grad():
    for i, (inputs, labels) in enumerate(test_loader):

        if i >= num_samples_to_display:
            break

        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)

        image = inputs[0].cpu().squeeze().numpy()
        true_mask = labels[0].cpu().squeeze().numpy()
        pred_mask = outputs[0].cpu().squeeze().numpy()
        pred_mask = (pred_mask > 0.5).astype(np.uint8)

        fig, axs = plt.subplots(1, 3, figsize=(9, 3))
        axs[0].imshow(image, cmap="gray")
        axs[0].set_title("Imagen original")
        axs[0].axis('off')

        axs[1].imshow(true_mask, cmap="gray")
        axs[1].set_title("Máscara verdadera")
        axs[1].axis('off')

        axs[2].imshow(pred_mask, cmap="gray")
        axs[2].set_title("Máscara predicha")
        axs[2].axis('off')

        plt.tight_layout()
        plt.show()

# %% [markdown]
# ## **Entregable**

# %% [markdown]
# Completar el código y analizar los resultados obtenidos.

# %% [markdown]
# Algunas conclusiones sobre el comportamiento y evaluacion del modelo:
# - En la fase de entrenamiento pude observar a traves de las curvas de pérdida de entrenamiento y validación que: tanto la pérdida de entrenamiento como la de validación disminuyen rápidamente hasta llegar a un cuarto de las epocas totales, lo que es un buen indicador de que el modelo está aprendiendo de los datos y ajustando los pesos correctamente. Luego de este punto, la curva de pérdida de validación no disminuye de manera significativa, si no, que oscila y aumenta su valor. Por lo que en este momento se aplica early stopping para guardar el modelo en el punto óptimo de entrenamiento.
#
# - Luego, al evaluar el modelo en el conjunto de prueba obtuvo las siguientes métricas de evaluación: **Accuracy: 95%** y **Coeficiente Dice: 92%**, lo que deja en evidencia que las predicciones del modelo coinciden en gran porcentaje con las máscaras reales.
